# %% [markdown]
# ## Read in the data and merged labels

# %%
import pandas as pd 
labels_data = pd.read_csv('data/labels.csv')

# Read the training.csv file
training_data = pd.read_csv('data/training.csv')
training_data = pd.merge(training_data, labels_data, on='label')

# Read the validations.csv file
validation_data = pd.read_csv('data/validations.csv')
validation_data = pd.merge(validation_data, labels_data, on='label')

# %%
validation_data
# Out:
#                                                 content label Type of Clause  \
# 0     Subscriber certifies to 9GAG, Inc that if Subs...   unc        Unknown
# 1     9GAG, Inc will use reasonable efforts to ensur...   unc        Unknown
# 2     Subscriber shall be responsible for obtaining ...   unc        Unknown
# 3     The Site and its contents are intended solely ...   unc        Unknown
# 4     Subscriber shall own all Subscriber Content th...   unc        Unknown
# ...                                                 ...   ...            ...
# 1268  We will give you 60-days’ notice by email or t...   unc        Unknown
# 1269  You and Zynga both consent to venue and person...    j3   Jurisdiction
# 1270  If you reside outside the United States, judic...    j3   Jurisdiction
# 1271  If We provide a translated version of these Te...   unc        Unknown
# 1272  If We do not enforce a provision of these Term...   unc        Unknown
#
#       Degree of Unfairness
# ...

# %% [markdown]
# ## Value count of Type of Clauses

# %%
training_label_counts = training_data['Type of Clause'].value_counts()
validation_label_counts = validation_data['Type of Clause'].value_counts()

print("Training Data Clause:")
print(training_label_counts)

print("\nValidation Data Clause:")
print(validation_label_counts)
# Out:
# Training Data Clause:
# Type of Clause
# Unknown                     2422
# Limitation of Liability      152
# Unilateral  Termination      107
# Unilateral Change            105
# Content Removal               54
# Contract by Using             47
# Jurisdiction                  44
# Choice of Law                 38
# Arbitration                   24
# Name: count, dtype: int64
#
# Validation Data Clause:
# Type of Clause
# Unknown                     1026
# Limitation of Liability       73
# Unilateral  Termination       48
# Unilateral Change             32
# Contract by Using             25
# Choice of Law                 22
# Jurisdiction                  22
# Content Removal               16
# Arbitration                    9
# Name: count, dtype: int64

# %% [markdown]
# ## Distribution of Label Counts

# %%
import matplotlib.pyplot as plt

# Plot bar plot for training data label counts
plt.figure(figsize=(8, 6))
training_label_counts.plot(kind='bar')
plt.title('Training Data Label Counts')
plt.xlabel('Label')
plt.ylabel('Count')

# Add percentages to the bars
total = training_label_counts.sum()
for i, count in enumerate(training_label_counts):
    percentage = count / total * 100
    plt.text(i, count, f'{percentage:.2f}%', ha='center', va='bottom', fontsize=8)

plt.show()

# Plot bar plot for validation data label counts
plt.figure(figsize=(8, 6))
validation_label_counts.plot(kind='bar')
plt.title('Validation Data Label Counts')
plt.xlabel('Label')
plt.ylabel('Count')

# Add percentages to the bars
total = validation_label_counts.sum()
for i, count in enumerate(validation_label_counts):
    percentage = count / total * 100
    plt.text(i, count, f'{percentage:.2f}%', ha='center', va='bottom', fontsize=8)

plt.show()

# %% [markdown]
# ## Distribution of Degree of Unfairness

# %%
# Plot the grouped bar plot for training data with percentage
plt.figure(figsize=(10, 6))
ax = training_percentage.plot(kind='bar', stacked=True)
plt.title('Distribution of Degree of Unfairness in Training Data')
plt.xlabel('Type of Clause')
plt.ylabel('Percentage')

# Add percentages to the bars with smaller font size for non-zero values
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    percentage = height / 100
    if height != 0:
        ax.annotate(f'{percentage:.2f}%', (x + width/2, y + height/2), ha='center', va='center', fontsize=6)

# Place the legend outside the plot
ax.legend(title='Degree of Unfairness', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()

# Plot the grouped bar plot for validation data with percentage
plt.figure(figsize=(10, 6))
ax = validation_percentage.plot(kind='bar', stacked=True)
plt.title('Distribution of Degree of Unfairness in Validation Data')
plt.xlabel('Type of Clause')
plt.ylabel('Percentage')

# Add percentages to the bars with smaller font size for non-zero values
for p in ax.patches:
    width = p.get_width()
    height = p.get_height()
    x, y = p.get_xy() 
    percentage = height / 100
    if height != 0:
        ax.annotate(f'{percentage:.2f}%', (x + width/2, y + height/2), ha='center', va='center', fontsize=6)

# Place the legend outside the plot
ax.legend(title='Degree of Unfairness', bbox_to_anchor=(1.05, 1), loc='upper left')

plt.show()
